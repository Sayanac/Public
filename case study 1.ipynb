# %% [markdown]
# # Read the dataset to the python environment

# %%
import pandas as pd
cardata=pd.read_csv("cars_data.csv")
cardata
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # Check for the null values present in the dataset

# %%
cardata.isna().sum()
print(cardata.isna().sum())
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # Plot a bar graph of male vs female buyers participated in the sales

# %%
import numpy as np
bar= np.arange(1)
M = cardata[cardata['Buyer Gender']=='Male']['Buyer Gender'].count()
F= cardata[cardata['Buyer Gender']=='Female']['Buyer Gender'].count()
plt.bar(bar,M,width=0.50,color='blue',label='Male Buyers')
plt.bar(bar+0.50,F,width=0.50,color='pink',label='Female Buyers')
plt.legend()
plt.xticks(bar+0.25,['Gender'])
plt.ylabel('Count')
plt.title('Female and Male Buyers')
plt.show()

# %% [markdown]
# # Find the top 5 cars based on their sales price

# %%
car1=cardata['Sale Price'].nlargest(n=5).index
cardata['Make'][car1]
# Out:
# 5984    Volkswagen
# 1270          Audi
# 3460         Lexus
# 9032         Mazda
# 302          Lexus
# Name: Make, dtype: object

# %% [markdown]
# # Find the least 5 cars based on their Resell price

# %%
car2=cardata['Resell Price'].nsmallest(n=5).index
cardata['Make'][car2]
# Out:
# 2446     Chevrolet
# 4933           GMC
# 566         Jaguar
# 2538    Mitsubishi
# 5869      Infiniti
# Name: Make, dtype: object
