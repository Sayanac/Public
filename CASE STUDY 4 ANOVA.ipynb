# %%
import pandas as pd
data=pd.read_csv("sales_data_zone_wise.csv")

# %%
#reading the data set to pyton environment
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0    Month - 1   1483525   1748451   1523308   2267260
# 1    Month - 2   1238428   1707421   2212113   1994341
# 2    Month - 3   1860771   2091194   1282374   1241600
# 3    Month - 4   1871571   1759617   2290580   2252681
# 4    Month - 5   1244922   1606010   1818334   1326062
# 5    Month - 6   1534390   1573128   1751825   2292044
# 6    Month - 7   1820196   1992031   1786826   1688055
# 7    Month - 8   1625696   1665534   2161754   2363315
# 8    Month - 9   1652644   1873402   1755290   1422059
# 9   Month - 10   1852450   1913059   1754314   1608387
# 10  Month - 11   2004480   1740365   1317869   1970069
# 11  Month - 12   1537539   1875658   1237722   1460165
# 12  Month - 13   1254939   1588473   1348629   1733383
# 13  Month - 14   1821799   1844081   1617376   1872259
# 14  Month - 15   1128185   1804613   1767047   1234311
# 15  Month - 16   1491534   1542053   1882159   1590913
# ...

# %%
#checking the first 5 rows of the dataset
data.head()
# Out:
#        Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0  Month - 1   1483525   1748451   1523308   2267260
# 1  Month - 2   1238428   1707421   2212113   1994341
# 2  Month - 3   1860771   2091194   1282374   1241600
# 3  Month - 4   1871571   1759617   2290580   2252681
# 4  Month - 5   1244922   1606010   1818334   1326062

# %%
#checking the last 5 rows of the dataset
data.tail()
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D
# 24  Month - 25   1256333   1622671   1521792   1695122
# 25  Month - 26   1422853   1715465   1853636   1520406
# 26  Month - 27   1384426   1983163   1611169   1289160
# 27  Month - 28   1616640   1547991   2128022   2178267
# 28  Month - 29   1310654   1660092   1947119   1854412

# %%
#checking the information about the data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Month     29 non-null     object
#  1   Zone - A  29 non-null     int64
#  2   Zone - B  29 non-null     int64
#  3   Zone - C  29 non-null     int64
#  4   Zone - D  29 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.3+ KB

# %% [markdown]
# # Insight

# %% [markdown]
# from the above code we know that there are no NULL values present inside the dataset

# %%
data.shape
# Out:
# (29, 5)

# %% [markdown]
# # XYZ Company has offices in four different zones. The company wishes to investigate the following :

# %% [markdown]
# # ● The mean sales generated by each zone.

# %%
data.describe().round()
# Out:
#         Zone - A   Zone - B   Zone - C   Zone - D
# count       29.0       29.0       29.0       29.0
# mean   1540493.0  1755560.0  1772871.0  1842927.0
# std     261940.0   168390.0   333194.0   375016.0
# min    1128185.0  1527574.0  1237722.0  1234311.0
# 25%    1305972.0  1606010.0  1523308.0  1520406.0
# 50%    1534390.0  1740365.0  1767047.0  1854412.0
# 75%    1820196.0  1875658.0  2098463.0  2180416.0
# max    2004480.0  2091194.0  2290580.0  2364132.0

# %%
import warnings
warnings.filterwarnings("ignore")
data.mean().round()
# Out:
# Zone - A       1540493.0
# Zone - B       1755560.0
# Zone - C       1772871.0
# Zone - D       1842927.0
# Total Sales    6911851.0
# dtype: float64

# %%
import matplotlib.pyplot as plt 
data.mean().plot.bar(figsize=(8,8))
plt.title("Mean Sales generated by each Zone",fontsize=14)
plt.show()

# %% [markdown]
# # Insight

# %% [markdown]
# From the above code it is clear that Zone - D is having the highest mean sales,
#
# and Zone - A is having the lowest mean sales.

# %% [markdown]
# # ● Total sales generated by all the zones for each month

# %%
data['Total Sales']=data.iloc[:,1:5].sum(axis=1)

# %%
data
# Out:
#          Month  Zone - A  Zone - B  Zone - C  Zone - D
# 0    Month - 1   1483525   1748451   1523308   2267260
# 1    Month - 2   1238428   1707421   2212113   1994341
# 2    Month - 3   1860771   2091194   1282374   1241600
# 3    Month - 4   1871571   1759617   2290580   2252681
# 4    Month - 5   1244922   1606010   1818334   1326062
# 5    Month - 6   1534390   1573128   1751825   2292044
# 6    Month - 7   1820196   1992031   1786826   1688055
# 7    Month - 8   1625696   1665534   2161754   2363315
# 8    Month - 9   1652644   1873402   1755290   1422059
# 9   Month - 10   1852450   1913059   1754314   1608387
# 10  Month - 11   2004480   1740365   1317869   1970069
# 11  Month - 12   1537539   1875658   1237722   1460165
# 12  Month - 13   1254939   1588473   1348629   1733383
# 13  Month - 14   1821799   1844081   1617376   1872259
# 14  Month - 15   1128185   1804613   1767047   1234311
# 15  Month - 16   1491534   1542053   1882159   1590913
# ...

# %%
# here we can get the total sales generated for each month

# %%
df=data.nlargest(10,'Total Sales')
df=df.reset_index()
df=df.drop('index',axis=1)
df
# Out:
#         Month  Zone - A  Zone - B  Zone - C  Zone - D  Total Sales
# 0   Month - 4   1871571   1759617   2290580   2252681      8174449
# 1   Month - 8   1625696   1665534   2161754   2363315      7816299
# 2  Month - 24   1880820   1752873   2098463   2052591      7784747
# 3  Month - 22   1481619   1527574   2255729   2295079      7560001
# 4  Month - 28   1616640   1547991   2128022   2178267      7470920
# 5  Month - 21   1570152   2013615   1540016   2265814      7389597
# 6   Month - 7   1820196   1992031   1786826   1688055      7287108
# 7  Month - 14   1821799   1844081   1617376   1872259      7155515
# 8   Month - 2   1238428   1707421   2212113   1994341      7152303
# 9   Month - 6   1534390   1573128   1751825   2292044      7151387

# %% [markdown]
# # Insight

# %% [markdown]
# Month - 4 has generated the highest total sales.

# %% [markdown]
# # ● Check whether all the zones generate the same amount of sales

# %% [markdown]
# here One Way ANOVA test is used

# %% [markdown]
# setting up the hypothesis
#
# Ho : All the Zones generate the same amount of sales.
#
# Ha : All the Zones generate different amount of sales.
#
# significance level=5%, α=0.05

# %%
import scipy.stats as stats
fvalue,pvalue=stats.f_oneway(data['Zone - A'],data['Zone - B'],data['Zone - C'],data['Zone - D'])

# %%
print('fvalue:',fvalue.round(5))
print('pvalue:',pvalue.round(5))
# Out:
# fvalue: 5.67206
# pvalue: 0.00118

# %%
a=0.05
if a < pvalue :
    print('We fail to reject the NULL hypothesis')
else:
    print('Reject the NULL hypothesis')
# Out:
# Reject the NULL hypothesis

# %% [markdown]
# Insight

# %% [markdown]
# from the one way ANOVA test it is clear that we should reject the null hypothesis.

# %% [markdown]
# # Therefor all the Zones generate different amount of sales
